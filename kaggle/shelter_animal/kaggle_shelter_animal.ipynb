# %%
import pandas as pd

# %%
raw_shelter_animal = pd.read_csv('test.csv', )
raw_shelter_animal.head(10)
# Out:
#    ID        Name             DateTime AnimalType SexuponOutcome  \
# 0   1      Summer  2015-10-12 12:15:00        Dog  Intact Female
# 1   2    Cheyenne  2014-07-26 17:59:00        Dog  Spayed Female
# 2   3         Gus  2016-01-13 12:20:00        Cat  Neutered Male
# 3   4       Pongo  2013-12-28 18:12:00        Dog    Intact Male
# 4   5     Skooter  2015-09-24 17:59:00        Dog  Neutered Male
# 5   6        Beau  2015-06-23 11:17:00        Dog  Neutered Male
# 6   7        Bobo  2014-03-12 09:45:00        Cat  Neutered Male
# 7   8        Abby  2014-06-25 08:27:00        Cat  Spayed Female
# 8   9  Ruby Grace  2014-11-12 18:05:00        Dog  Spayed Female
# 9  10        Ruby  2014-04-07 17:41:00        Dog  Spayed Female
#
#   AgeuponOutcome                           Breed              Color
# 0      10 months          Labrador Retriever Mix          Red/White
# 1        2 years  German Shepherd/Siberian Husky          Black/Tan
# ...

# %%
raw_shelter_animal.shape
# Out:
# (11456, 8)

# %%
raw_shelter_animal.loc[:,'AnimalType'].value_counts()
# Out:
# Dog    6656
# Cat    4800
# Name: AnimalType, dtype: int64

# %%
raw_shelter_animal['Color'].unique()
# Out:
# array(['Red/White', 'Black/Tan', 'Brown Tabby', 'Tricolor', 'White',
#        'Brown/White', 'Brown Tabby/White', 'Black/Cream', 'White/Black',
#        'Blue/White', 'Brown Brindle', 'Black/Brown', 'White/Tricolor',
#        'Torbie', 'Black', 'White/Tan', 'Tortie', 'Tan', 'Black Smoke',
#        'Brown', 'Black/White', 'Red Merle/White', 'Gold', 'Orange Tabby',
#        'Blue', 'Blue Tabby', 'Orange Tabby/White', 'Brown Brindle/White',
#        'Chocolate', 'Blue Tabby/White', 'White/Brown', 'Brown/Tan',
#        'White/Red', 'Tan/White', 'Gray/Black', 'White/Brown Tabby',
#        'Black Brindle', 'Black Tabby', 'Calico Point', 'Calico', 'Sable',
#        'Yellow/White', 'Brown/Black', 'Tortie Point', 'Red', 'Yellow/Tan',
#        'Sable/White', 'Cream Tabby', 'Brown Merle', 'Black Brindle/White',
#        'Lilac Point', 'Lynx Point', 'Cream', 'Blue/Tan', 'Yellow',
#        'Buff/White', 'White/Brown Brindle', 'Gray/White',
# ...

# %%
from datetime import datetime

# %%
raw_shelter_animal['DateTime'] = raw_shelter_animal['DateTime'].apply(lambda date_time: datetime.strptime(date_time, '%Y-%m-%d %H:%M:%S'))

# %%
raw_shelter_animal['Name'].nunique()
# Out:
# 3712

# %%
raw_shelter_animal.head(10)
# Out:
#    ID        Name            DateTime AnimalType SexuponOutcome  \
# 0   1      Summer 2015-10-12 12:15:00        Dog  Intact Female
# 1   2    Cheyenne 2014-07-26 17:59:00        Dog  Spayed Female
# 2   3         Gus 2016-01-13 12:20:00        Cat  Neutered Male
# 3   4       Pongo 2013-12-28 18:12:00        Dog    Intact Male
# 4   5     Skooter 2015-09-24 17:59:00        Dog  Neutered Male
# 5   6        Beau 2015-06-23 11:17:00        Dog  Neutered Male
# 6   7        Bobo 2014-03-12 09:45:00        Cat  Neutered Male
# 7   8        Abby 2014-06-25 08:27:00        Cat  Spayed Female
# 8   9  Ruby Grace 2014-11-12 18:05:00        Dog  Spayed Female
# 9  10        Ruby 2014-04-07 17:41:00        Dog  Spayed Female
#
#   AgeuponOutcome                           Breed              Color
# 0      10 months          Labrador Retriever Mix          Red/White
# 1        2 years  German Shepherd/Siberian Husky          Black/Tan
# ...

# %%
raw_shelter_animal['AgeuponOutcome'].unique()
# Out:
# array(['10 months', '2 years', '1 year', '4 months', '3 years',
#        '13 years', '6 months', '3 months', '5 months', '5 years',
#        '4 years', '3 weeks', '1 week', '2 months', '9 months', '4 days',
#        '2 weeks', '7 months', '9 years', '1 month', '12 years', '1 weeks',
#        '6 days', '6 years', '8 years', '8 months', '4 weeks', '7 years',
#        '10 years', '5 days', '17 years', '3 days', '15 years', '11 years',
#        '14 years', '11 months', nan, '2 days', '1 day', '16 years',
#        '20 years', '0 years', '22 years', '18 years', '5 weeks',
#        '19 years'], dtype=object)

# %%
func = lambda str_date: str_date.split(' ')
raw_shelter_animal['AgeuponOutcome'].apply(func)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-4e73d9f5e692> in <module>()
#       1 func = lambda str_date: str_date.split(' ')
# ----> 2 raw_shelter_animal['AgeuponOutcome'].apply(func)
#
# ~/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-60-4e73d9f5e692> in <lambda>(str_date)
# ----> 1 func = lambda str_date: str_date.split(' ')
#       2 raw_shelter_animal['AgeuponOutcome'].apply(func)
#
# AttributeError: 'float' object has no attribute 'split'
